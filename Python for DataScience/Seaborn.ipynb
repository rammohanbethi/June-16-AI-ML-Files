# %%
import seaborn as sns

# %%
sns.__version__
# Out:
# '0.11.0'

# %%
tips=sns.load_dataset('tips')

# %%
import pandas as pd
tips=pd.read_csv('tips.csv')

# %%
tips
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
tips.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips,color='red',hue='smoker')

# %%
import matplotlib.pyplot as plt
plt.scatter(tips['total_bill'],tips['tip'],color='blue')

# %%
sns.lineplot(x='size',y='tip',data=tips)

# %%
plt.plot(tips['size'],tips['tip'])

# %%
#distribution plot
sns.histplot(tips['tip'])

# %%
#distribution plot
from scipy.stats import norm
sns.kdeplot(tips['tip'])

# %%
tips['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
sns.barplot(x='day',y='tip',data=tips)

# %%
sns.barplot(x='time',y='tip',data=tips)

# %%
sns.set_style('whitegrid')
sns.boxplot(x='day',y='total_bill',data=tips,color='red',width=0.4)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
#temperatues
70,71,73,70,70,69,70,72,71,300,71,69
#step2. arranging data points from lowest to highest
69,69,70,70,70,70,70.5,71,71,71,72,73,300,

median(Q2) - 50% = 70+71/2=70.5

#middle number between median (Q2) and minimum number 
lower (Q1) -25% = 70+70/2=70 - 70
#middle number between median (Q2) and maximum number 
upper(Q3) - 75% = 71+72/2=71.5 71.5

#Q3-Q1=71.5-70=1.5 = IQR

1.5*1.5 = 2.25

#q3 = 71.5+2.25=73.75
#q1=70 = 70-2.25=67.75 - 

1.5*3=4.5
71.5+4.5=76
70-4.5=65.5

# %%
sns.pairplot(tips,hue='time')

# %%
tips.corr() #-1 to 1 0
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
0.5

>0.5 - higlycorrele
<0.5 partially corr

>-0.5 partially negative corr
<-0.5 highy correlation

# %%
p=cov(x,y)/x,y

# %%
sns.heatmap(tips.corr(),annot=True,fmt='.1g')

# %%
sns.heatmap(tips.corr(),annot=True,vmin=-1,vmax=1,center=0)

# %%
#Blues, Greys, Purples, OrRd
sns.heatmap(tips.corr(),annot=True,vmin=-1,vmax=1,center=0,cmap='OrRd',
           linewidth=3, linecolor='black')

# %%
#tril
#triu
import numpy as np
a=np.tril(tips.corr())
sns.heatmap(tips.corr(),annot=True,mask=a)

# %%
import numpy as np
a=np.triu(tips.corr())
sns.heatmap(tips.corr(),annot=True,mask=a)
